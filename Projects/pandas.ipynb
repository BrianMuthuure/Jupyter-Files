# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/thucheiz/Desktop/Pandas Demo/data/survey_results_public.csv', index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
schema_df = pd.read_csv('C:/Users/thucheiz/Desktop/Pandas Demo/data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
schema_df.sort_values(by='Column')
# Out:
#                           Column  \
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 2                       Hobbyist
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 1                     MainBranch
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# ...

# %%
df.loc[1, 'Hobbyist']
# Out:
# 'Yes'

# %%
high_salary = df['ConvertedComp'] > 900000

# %%
df.loc[high_salary,['Country', 'ConvertedComp']].head(20)
# Out:
#                    Country  ConvertedComp
# Respondent
# 18           United States      1260000.0
# 57           United States      1620000.0
# 65           United States      1176000.0
# 123          United States      2000000.0
# 125          United States      2000000.0
# 193          United States      2000000.0
# 196          United States      1920000.0
# 281          United States      1104000.0
# 313                 Canada      1000000.0
# 503          United States      1500000.0
# 665          United States      2000000.0
# 685         United Kingdom       958584.0
# 699          United States      2000000.0
# 724          United States      2000000.0
# 818          United States      2000000.0
# 839          United States      1260000.0
# 903         United Kingdom      1000000.0
# 935                 Canada      1000000.0
# 939         United Kingdom      1000000.0
# 954            Switzerland      1000000.0

# %%
countries = ['United States', 'Switzerland', 'United Kingdom', 'Canada', 'India']

# %%
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 2        United Kingdom
# 5         United States
# 7                 India
# 8         United States
# 10       United Kingdom
# 11       United Kingdom
# 14        United States
# 16       United Kingdom
# 17        United States
# 18        United States
# 19        United States
# 22                India
# 26               Canada
# 27        United States
# 30       United Kingdom
# 32               Canada
# 35        United States
# 36       United Kingdom
# 39       United Kingdom
# 40        United States
# 41        United States
# 42        United States
# 43        United States
# 47       United Kingdom
# 48        United States
# 49        United States
# 51               Canada
# 52       United Kingdom
# 53        United States
# 54        United States
#               ...
# 38854             India
# 42314     United States
# 42965             India
# 43211     United States
# 44176     United States
# 44880             India
# 45374     United States
# ...

# %%
# Display all strings that contain python
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith'].head(10)
# Out:
# Respondent
# 3                             Objective-C;Python;Swift
# 8                                           Python;SQL
# 10                 HTML/CSS;Java;JavaScript;Python;SQL
# 13                                 C;JavaScript;Python
# 15    Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# 17               C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 22                                         Java;Python
# 26                                   JavaScript;Python
# 27         Bash/Shell/PowerShell;C;C++;Java;Python;SQL
# 28                                            Python;R
# Name: LanguageWorkedWith, dtype: object

# %%
df.sort_values(by='Country', inplace=True)

# %%
df
# Out:
#                                         MainBranch Hobbyist   Age  \
# Respondent
# 8631        I am a student who is learning to code       No   NaN
# 25001               I am a developer by profession       No   NaN
# 58171       I am a student who is learning to code      Yes  23.0
# 42668               I am a developer by profession      Yes   NaN
# 51509               I am a developer by profession       No  28.0
# 37951       I am a student who is learning to code      Yes   NaN
# 28374               I am a developer by profession      Yes   NaN
# 7616                I am a developer by profession       No  24.0
# 43966       I am a student who is learning to code      Yes  25.0
# 62698               I am a developer by profession      Yes   NaN
# 51532               I am a developer by profession      Yes   NaN
# 36574               I am a developer by profession       No   NaN
# 43946       I am a student who is learning to code      Yes   NaN
# ...

# %%
df[['Country', 'ConvertedComp']]
# Out:
#                 Country  ConvertedComp
# Respondent
# 8631        Afghanistan            NaN
# 25001       Afghanistan            NaN
# 58171       Afghanistan            NaN
# 42668       Afghanistan            NaN
# 51509       Afghanistan        20220.0
# 37951       Afghanistan            NaN
# 28374       Afghanistan       130000.0
# 7616        Afghanistan            NaN
# 43966       Afghanistan            NaN
# 62698       Afghanistan            NaN
# 51532       Afghanistan            NaN
# 36574       Afghanistan            NaN
# 43946       Afghanistan            NaN
# 65381       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 35753       Afghanistan          780.0
# 43808       Afghanistan            NaN
# 37159       Afghanistan            NaN
# 44555       Afghanistan            NaN
# 35687       Afghanistan            NaN
# 37605       Afghanistan            NaN
# 44556       Afghanistan            NaN
# 23798       Afghanistan            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist   Age  \
# Respondent
# 54263       I am a developer by profession      Yes  29.0
# 5725        I am a developer by profession       No  26.0
# 43430       I am a developer by profession      Yes  33.0
# 59279       I am a developer by profession      Yes   NaN
# 46711       I am a developer by profession      Yes   NaN
# 1793        I am a developer by profession      Yes  27.0
# 3072        I am a developer by profession      Yes  32.0
# 3045        I am a developer by profession      Yes  35.0
# 1413        I am a developer by profession      Yes  25.0
# 3261        I am a developer by profession      Yes  34.0
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 54263                         10   Weekly  7.000000e+04      2000000.0
# 5725                          14  Monthly  1.800000e+05      2000000.0
# 43430                         17  Monthly  1.710000e+05      2000000.0
# ...

# %%
df['ConvertedComp'].mean()
# Out:
# 103756.05014961446

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist'].count()
# Out:
# 64416

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['PlatformWorkedWith'].value_counts(normalize=True)
# Out:
# Windows                                                                                                                                 0.088591
# Linux;Windows                                                                                                                           0.045707
# Linux                                                                                                                                   0.039225
# Android                                                                                                                                 0.022306
# Microsoft Azure;Windows                                                                                                                 0.018498
# Docker;Linux                                                                                                                            0.017124
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
# France                                 1898
# Brazil                                 1818
# Netherlands                            1343
# Poland                                 1278
# Australia                              1208
# Spain                                  1161
# Italy                                  1117
# Russian Federation                     1092
# Sweden                                  886
# Pakistan                                809
# Turkey                                  777
# Israel                                  653
# Switzerland                             629
# Bangladesh                              609
# Romania                                 604
# Nigeria                                 593
# ...

# %%
filt = df['Country'] == 'United States'

# %%
df.loc[filt]['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                                                                       842
# Linux;Windows                                                                                                                                 378
# Linux                                                                                                                                         358
# Microsoft Azure;Windows                                                                                                                       237
# Linux;MacOS                                                                                                                                   134
# Docker;Linux                                                                                                                                  131
# ...

# %%
# Count all platforms worked with in every country
country_grp = df.groupby(['Country'])
country_grp['PlatformWorkedWith'].value_counts()
# Out:
# Country      PlatformWorkedWith
# Afghanistan  Android                                                                                                                                                                      7
#              Windows                                                                                                                                                                      5
#              Android;Windows                                                                                                                                                              4
#              Android;Linux;Windows;WordPress                                                                                                                                              3
#              Android;Google Cloud Platform;Windows                                                                                                                                        2
# ...

# %%
country_grp['PlatformWorkedWith'].value_counts().loc['India']
# Out:
# PlatformWorkedWith
# Windows                                                                  628
# Android                                                                  384
# Linux;Windows                                                            336
# Linux                                                                    301
# Android;Windows                                                          123
# iOS                                                                      114
# Android;Linux;Windows                                                    102
# AWS                                                                       86
# Android;iOS                                                               86
# AWS;Linux                                                                 77
# Windows;WordPress                                                         77
# WordPress                                                                 76
# ...

# %%
# Median Salary for each country
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                                   15163.5
# Albania                                       15900.0
# Algeria                                        9432.0
# Andorra                                       88640.0
# Angola                                         5292.0
# Antigua and Barbuda                               NaN
# Argentina                                     17520.0
# Armenia                                       21066.0
# Australia                                     76831.0
# Austria                                       51888.0
# Azerbaijan                                    11988.0
# Bahamas                                       86706.0
# Bahrain                                       40196.0
# Bangladesh                                     7068.0
# Barbados                                      25074.0
# Belarus                                       27600.0
# Belgium                                       45396.0
# ...

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['ConvertedComp'].agg(['mean', 'median'])
# Out:
#                                                     mean    median
# Country
# Afghanistan                                148290.125000   15163.5
# Albania                                     25611.000000   15900.0
# Algeria                                     10362.812500    9432.0
# Andorra                                     88640.000000   88640.0
# Angola                                       5292.000000    5292.0
# Antigua and Barbuda                                  NaN       NaN
# Argentina                                   29010.033473   17520.0
# Armenia                                     30421.285714   21066.0
# Australia                                  146165.814767   76831.0
# Austria                                     83077.661342   51888.0
# Azerbaijan                                  14909.142857   11988.0
# Bahamas                                     86706.000000   86706.0
# Bahrain                                     39592.000000   40196.0
# ...

# %%
filt = df['Country'] == 'India'

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
filt = df['Country'] == 'United States'

# %%
us_df = df.loc[filt]

# %%
us_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1157                           I am a developer by profession       No  30.0
# 3003                           I am a developer by profession      Yes  34.0
# 1791        I am not primarily a developer, but I write co...       No  43.0
# 1436                           I am a developer by profession      Yes  53.0
# 57952                          I am a developer by profession      Yes  45.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# 1157               25   Yearly    84500.0        84500.0  United States
# 3003               16      NaN        NaN            NaN  United States
# 1791                8      NaN        NaN            NaN  United States
# 1436               15   Yearly   125000.0       125000.0  United States
# 57952              15   Yearly   125000.0       125000.0  United States
#
# ...

# %%
us_df.to_csv('modified.csv')

# %%
us_df.to_csv('modified.tsv', sep='\t')

# %%
from sqlalchemy import create_engine
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-63-21530d404eb7> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'
